# %% [markdown]
# <h1><center>Linear Regression: No interactions btn Independent Variables</center></h1>

# %% [markdown]
# ![linear_regression.png](attachment:linear_regression.png)

# %% [markdown]
# <h1><center>Interactions vs. No Interactions</center></h1>

# %% [markdown]
# ![interactions.png](attachment:interactions.png)

# %% [markdown]
# <h1><center>Neural Networks</center></h1>

# %% [markdown]
# ![deep_learning.png](attachment:deep_learning.png)

# %% [markdown]
# <h1><center>Deep Learning: Hidden Layers</center></h1>

# %% [markdown]
# ![deep_learning_interactions.png](attachment:deep_learning_interactions.png)
